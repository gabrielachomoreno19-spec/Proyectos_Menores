# %%
alumno = {
    "nombre": "Javier",
    "edad": 24,
    "carrera": "Ingenieria"
}

print(alumno["nombre"])
print(alumno["edad"])

# Agregar un dato
alumno["ciudad"] = "Santiago"

# Modificar un dato
alumno["edad"] = 32

# Recorrer el diccionario
for clave, valor in alumno.items():
    print(clave, ":", valor)
# Out:
# Javier
# 24
# nombre : Javier
# edad : 32
# carrera : Ingenieria
# ciudad : Santiago

# %% [markdown]
# #Ejercicio 1: Crear un diccionario que almacene nombres y números de teléfono.
#
# Debe permitir:
#
# 1. Agregar 3 contactos.
# 2. Mostrar todos los contactos.
# 3. Buscar el teléfono de una persona.

# %% [markdown]
# #Ejercicio 2: Contador de frutas (Fácil-Medio)
#
# Dada una lista de frutas:
#
#
# ```
# frutas = ["manzana", "pera", "manzana", "uva", "pera", "manzana"]
# ```
# Crear un diccionario que indique cuántas veces aparece cada fruta.
#
# Resultado esperado
#
#
# ```
# {
#     "manzana": 3,
#     "pera": 2,
#     "uva": 1
# }
# ```

# %% [markdown]
# #Ejercicio 3: Registro de notas (Medio)
#
# Crear un programa que almacene estudiantes y sus notas.
#
# Utilizar un diccionario donde:
#
#
# ```
# {
#     "Juan": [60, 55, 70],
#     "Ana": [70, 68, 65]
# }
# ```
# Debe permitir:
#
# 1. Ingresar 3 estudiantes.
# 2. Ingresar 3 notas por estudiante.
# 3. Mostrar el promedio de cada estudiante.
#
# Ejemplo
#
# Salida:
#
#
# ```
# Juan: 61.67
# Ana: 67.67
# ```

# %% [markdown]
# #Ejercicio 4: Sistema de ventas por vendedor (Difícil)
#
# Crear un programa que registre las ventas de varios vendedores.
#
# La estructura debe ser:
#
#
# ```
# ventas = {
#     "Pedro": [15000, 20000, 18000],
#     "Ana": [22000, 30000],
#     "Luis": [10000, 12000, 15000]
# }
# ```
# Crear un menú que permita:
#
#
# ```
# 1. Registrar venta
# 2. Ver ventas de un vendedor
# 3. Ver total vendido por vendedor
# 4. Mostrar vendedor con más ventas
# 5. Salir
# ```
#
# Ejemplo de salida
# ```
# Pedro vendió: $53000
# Ana vendió: $52000
# Luis vendió: $37000
#
# Mejor vendedor: Pedro
# ```
